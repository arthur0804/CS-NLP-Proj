# %% [markdown]
# ### 0.Crawl suspended stock list from NASDAQ

# %%
import re
from bs4 import BeautifulSoup
import urllib
import pandas as pd
import requests
import json

# %%
url = 'https://listingcenter.nasdaq.com/IssuersPendingSuspensionDelisting.aspx'
response = urllib.request.urlopen(url)
soup = BeautifulSoup(response, 'html.parser')

# %%
table = soup.find('table',{'class':'rgMasterTable'})

# %%
stock_list = []
for tr in table.tbody.findAll('tr'):
    row = []
    for td in tr.findAll('td'):
        text = td.getText()
        if text == '\xa0':
            text = 'None'
        row.append(text)
    stock_list.append(row)

# %%
df = pd.DataFrame(stock_list)
df.columns = ['Issuer Name','Symbol','Reason','Status','Effective Date','Form 25 Date']

# %%
df
# Out:
#                                     Issuer Name Symbol  \
# 0                       Altus Midstream Company  ALTMW
# 1              Concrete Pumping Holdings, Inc.   BBCPW
# 2               Eco-Stim Energy Solutions, Inc.   ESES
# 3                            Elbit Imaging Ltd.  EMITF
# 4             Helios and Matheson Analytics Inc   HMNY
# 5                                 Imperva, Inc.   IMPV
# 6                           Loxo Oncology, Inc.   LOXO
# 7                                MINDBODY, Inc.     MB
# 8                             MiMedx Group, Inc   MDXG
# 9   National American University Holdings, Inc.   NAUH
# 10                 Organogenesis Holdings Inc.   ORGOW
# 11                    ReShape Lifesciences Inc.   RSLS
# 12                       Real Goods Solar, Inc.   RGSE
# 13                           Select Income REIT    SIR
# 14        Simplicity Esports and Gaming Company   WINR
# 15        Simplicity Esports and Gaming Company  WINRW
# 16                   Super Micro Computer, Inc.   SMCI
# 17                          Waitr Holdings Inc.  WTRHW
# 18                 Yulong Eco-Materials Limited   YECO
# 19                           athenahealth, Inc.   ATHN
# 20                                   iPass Inc.   IPAS
#
#                        Reason     Status Effective Date Form 25 Date
# 0   Regulatory/Non Compliance  Suspended     12/20/2018         None
# 1   Regulatory/Non Compliance  Suspended      1/17/2019         None
# 2   Regulatory/Non Compliance  Suspended       1/2/2019         None
# 3   Regulatory/Non Compliance  Suspended      2/11/2019         None
# 4   Regulatory/Non Compliance  Suspended      2/13/2019         None
# 5          Acquisition/Merger  Suspended      1/11/2019         None
# 6          Acquisition/Merger  Suspended      2/19/2019    2/15/2019
# 7          Acquisition/Merger  Suspended      2/19/2019    2/15/2019
# 8   Regulatory/Non Compliance  Suspended      11/8/2018         None
# 9                       Other  Suspended      1/22/2019         None
# 10  Regulatory/Non Compliance  Suspended       1/8/2019         None
# 11  Regulatory/Non Compliance  Suspended     12/31/2018         None
# 12  Regulatory/Non Compliance  Suspended      2/15/2019         None
# 13         Acquisition/Merger  Suspended       1/2/2019         None
# 14  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 15  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 16  Regulatory/Non Compliance  Suspended      8/23/2018         None
# 17  Regulatory/Non Compliance  Suspended     12/27/2018         None
# 18  Regulatory/Non Compliance  Suspended     12/14/2018         None
# 19         Acquisition/Merger  Suspended      2/12/2019    2/11/2019
# 20         Acquisition/Merger  Suspended      2/14/2019    2/13/2019

# %% [markdown]
# #### Filter results with the status, as some may resume trading.

# %%
suspended_df = df[df['Status'] == "Suspended"]
suspended_df
# Out:
#                                     Issuer Name Symbol  \
# 0                       Altus Midstream Company  ALTMW
# 1              Concrete Pumping Holdings, Inc.   BBCPW
# 2               Eco-Stim Energy Solutions, Inc.   ESES
# 3                            Elbit Imaging Ltd.  EMITF
# 4             Helios and Matheson Analytics Inc   HMNY
# 5                                 Imperva, Inc.   IMPV
# 6                           Loxo Oncology, Inc.   LOXO
# 7                                MINDBODY, Inc.     MB
# 8                             MiMedx Group, Inc   MDXG
# 9   National American University Holdings, Inc.   NAUH
# 10                 Organogenesis Holdings Inc.   ORGOW
# 11                    ReShape Lifesciences Inc.   RSLS
# 12                       Real Goods Solar, Inc.   RGSE
# 13                           Select Income REIT    SIR
# 14        Simplicity Esports and Gaming Company   WINR
# 15        Simplicity Esports and Gaming Company  WINRW
# 16                   Super Micro Computer, Inc.   SMCI
# 17                          Waitr Holdings Inc.  WTRHW
# 18                 Yulong Eco-Materials Limited   YECO
# 19                           athenahealth, Inc.   ATHN
# 20                                   iPass Inc.   IPAS
#
#                        Reason     Status Effective Date Form 25 Date
# 0   Regulatory/Non Compliance  Suspended     12/20/2018         None
# 1   Regulatory/Non Compliance  Suspended      1/17/2019         None
# 2   Regulatory/Non Compliance  Suspended       1/2/2019         None
# 3   Regulatory/Non Compliance  Suspended      2/11/2019         None
# 4   Regulatory/Non Compliance  Suspended      2/13/2019         None
# 5          Acquisition/Merger  Suspended      1/11/2019         None
# 6          Acquisition/Merger  Suspended      2/19/2019    2/15/2019
# 7          Acquisition/Merger  Suspended      2/19/2019    2/15/2019
# 8   Regulatory/Non Compliance  Suspended      11/8/2018         None
# 9                       Other  Suspended      1/22/2019         None
# 10  Regulatory/Non Compliance  Suspended       1/8/2019         None
# 11  Regulatory/Non Compliance  Suspended     12/31/2018         None
# 12  Regulatory/Non Compliance  Suspended      2/15/2019         None
# 13         Acquisition/Merger  Suspended       1/2/2019         None
# 14  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 15  Regulatory/Non Compliance  Suspended      1/25/2019         None
# 16  Regulatory/Non Compliance  Suspended      8/23/2018         None
# 17  Regulatory/Non Compliance  Suspended     12/27/2018         None
# 18  Regulatory/Non Compliance  Suspended     12/14/2018         None
# 19         Acquisition/Merger  Suspended      2/12/2019    2/11/2019
# 20         Acquisition/Merger  Suspended      2/14/2019    2/13/2019

# %% [markdown]
# ### 1. Build query structure
# #### query_list0 is for Google News; query_list1 is for Globenewswire

# %%
ticker = df.to_dict('index')

# %%
def build_query_list():
    query_list0 = []
    query_list1 = []
    for i in ticker:
        comp = re.sub(r'[,\.]',' ',ticker[i]['Issuer Name']).split()
        str_comp = '+'.join(comp)
        str_comp1 = ' '.join(comp)
        comp.append(ticker[i]['Symbol'])
        query = '+'.join(comp)
        query1 = ' '.join(comp)
        query_list0.append(query)
        query_list1.append(query1)
    return (query_list0, query_list1)

# %%
(query_list0, query_list1) = build_query_list()

# %% [markdown]
# #### After testing different combinations, we found that company_name+ticker is best for Globenewswire, while company_name+ticker+"stock"+"suspended" is bester for Google News.
#
# #### After testing different combinations of selecting the top-k retrieved results, we found that simply selecting the top 1 result from both news sources give a nice peroformance.

# %% [markdown]
# ### 2.1 Google News Crawler

# %%
# return top 1 results
def parseSingleNews(query):
    url = 'https://news.google.com/rss/search?q='+query+'+stock+suspend&hl=en-US&gl=US&ceid=US:en'
    response = urllib.request.urlopen(url)  
    soup = BeautifulSoup(response, 'html.parser')
    
    channel = soup.find('channel')
    news_list = []
    for item in soup.findAll('item')[0:1]:
        des = ''
        abst = ''
        description = item.find('description').get_text()
        match = re.search(r'(href=")(.*)(" target)',description)
        match1 = re.search(r'(<p>)(.*)(</p>)',description)
        if (match):
            des = match.group(2)
        if (match1):
            abst = match1.group(2)
        news_item = {
            'title':item.find('title').get_text(),
            'pubdate':item.find('pubdate').get_text(),
            'link':des,
            'abstract':abst
        }
        news_list.append(news_item)
    return news_list

# %%
def allQuery(query_list):
    dict = {}
    for q in query_list:
        q1 = q.replace('+',' ')
        news_list = parseSingleNews(q)
        dict[q1]=news_list
    return dict

# %%
google_news = allQuery(query_list0)

# %% [markdown]
# ### 2.2 Globenewswire Crawler

# %%
query_list2 = []
for q in query_list1:
    qry = {'keyword':q}
    query_list2.append(qry)

# %%
# return top 1 results
def parseSingleNews1(query):
    r = requests.get('https://globenewswire.com/Search', params=query)
    result = BeautifulSoup(r.text,'html.parser')
    contents = result.find_all("div", attrs = {"class" : "results-link"})
    news_list = []
    for content in contents[0:1]: 
        a = content.find("h1", attrs = {"class" : "post-title16px"}).find("a")
        title = a.text
        pubdate = content.find("span",attrs = {"class" : "dt-green"}).get_text()
        link = a['href']
        abstract = content.find_all("p")[1].text
        news_item = {
            'title':title,
            'pubdate':pubdate,
            'link':'https://globenewswire.com/'+link,
            'abstract':abstract
        }
        news_list.append(news_item)
    return news_list

# %%
def allQuery1(query_list):
    dict = {}
    for q in query_list:
        news_list = parseSingleNews1(q)
        dict[q['keyword']]=news_list
    return dict

# %%
ss = parseSingleNews1(query_list2[0])
# ss

# %%
globe_news = allQuery1(query_list2)

# %% [markdown]
# # Merge two sets

# %%
all_news = {}
for key in google_news:
    all_news[key] = google_news[key]
    all_news[key] += globe_news[key]

# %%
for k,v in all_news.items():
    print("Company name: {}".format(k))
    for i in v:
        print("\tRetrieved result:\t{}".format(i))
    print("------------------------------------\n")
# Out:
# Company name: Altus Midstream Company ALTMW
# 	Retrieved result:	{'title': 'Altus Midstream Company Announces Warrant Delisting from the Nasdaq; Class A Common Stock Will Continue to Trade on the Nasdaq - GlobeNewswire', 'pubdate': 'Fri, 14 Dec 2018 08:00:00 GMT', 'link': 'https://globenewswire.com/news-release/2018/12/14/1667521/0/en/Altus-Midstream-Company-Announces-Warrant-Delisting-from-the-Nasdaq-Class-A-Common-Stock-Will-Continue-to-Trade-on-the-Nasdaq.html', 'abstract': 'HOUSTON, Dec. 14, 2018 (GLOBE NEWSWIRE) -- Altus Midstream Company (Nasdaq: ALTM, ALTMW) (“Altus Midstream” or the “company”) today announced ...'}
# 	Retrieved result:	{'title': 'Altus Midstream Company Acquires 15 Percent of Gulf Coast Express Pipeline', 'pubdate': 'December 19, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/19/1669403/0/en/Altus-Midstream-Company-Acquires-15-Percent-of-Gulf-Coast-Express-Pipeline.html', 'abstract': 'HOUSTON, Dec.  19, 2018  (GLOBE NEWSWIRE) -- Altus Midstream Company (Nasdaq: ALTM, ALTMW) today announced its subsidiary, Altus Midstream LP, has exercised and closed its option with Kinder Morgan ...'}
# ------------------------------------
#
# Company name: Concrete Pumping Holdings Inc BBCPW
# 	Retrieved result:	{'title': 'Form 10-KT Concrete Pumping Holding For: Dec 05 - StreetInsider.com', 'pubdate': 'Tue, 29 Jan 2019 08:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+10-KT+Concrete+Pumping+Holding+For%3A+Dec+05/15050179.html', 'abstract': 'UNITED STATES. SECURITIES AND EXCHANGE COMMISSION. Washington, D.C. 20549. FORM 10-K. (Mark One). ¨, ANNUAL REPORT PURSUANT TO ...'}
# 	Retrieved result:	{'title': 'Concrete Pumping Holdings Sets Fourth Quarter and Fiscal Year 2018 Earnings Conference Call for Tuesday, January 29, 2019', 'pubdate': 'January 16, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/16/1696721/0/en/Concrete-Pumping-Holdings-Sets-Fourth-Quarter-and-Fiscal-Year-2018-Earnings-Conference-Call-for-Tuesday-January-29-2019.html', 'abstract': 'DENVER, Jan.  16, 2019  (GLOBE NEWSWIRE) -- Concrete Pumping Holdings, Inc. (Nasdaq: BBCP, BBCPW) (“CPH” or the “Company”), a leading provider of concrete pumping services and concrete waste ...'}
# ------------------------------------
#
# Company name: Eco-Stim Energy Solutions Inc ESES
# 	Retrieved result:	{'title': 'ECO-STIM ENERGY SOLUTIONS, INC. (NASDAQ:ESES) Files An 8-K Completion of Acquisition or Disposition of Assets - Market Exclusive', 'pubdate': 'Tue, 29 Jan 2019 08:00:00 GMT', 'link': 'https://marketexclusive.com/eco-stim-energy-solutions-inc-nasdaqeses-files-an-8-k-completion-of-acquisition-or-disposition-of-assets/2019/01/', 'abstract': 'ECO-STIM ENERGY SOLUTIONS, INC. (NASDAQ:ESES) Files An 8-K Completion of Acquisition or Disposition of Assets Item 2.01 Completion of Acquisition or ...'}
# 	Retrieved result:	{'title': 'Eco-Stim Energy Solutions Releases Third Quarter Numbers', 'pubdate': 'November 14, 2018', 'link': 'https://globenewswire.com//news-release/2018/11/14/1651776/0/en/Eco-Stim-Energy-Solutions-Releases-Third-Quarter-Numbers.html', 'abstract': 'HOUSTON, TEXAS, Nov.  14, 2018  (GLOBE NEWSWIRE) -- Eco-Stim Energy Solutions, Inc. (NASDAQ: ESES) (“EcoStim” or the “Company”) today filed its quarterly report on Form 10-Q with the U.S. Securities ...'}
# ------------------------------------
#
# Company name: Elbit Imaging Ltd EMITF
# 	Retrieved result:	{'title': 'ELBIT IMAGING ANNOUNCES SALE OF ADDITIONAL ELBIT MEDICAL SHARES - NASDAQ.com - Nasdaq', 'pubdate': 'Wed, 28 Nov 2018 08:00:00 GMT', 'link': 'https://www.nasdaq.com/press-release/elbit-imaging-announces-sale-of-additional-elbit-medical-shares-20181128-00816', 'abstract': 'Tel Aviv, Israel, Nov. 28, 2018-- Elbit Imaging Ltd. announced today, further to its press releases dated August 8, 2018, September 6, 2018,.'}
# 	Retrieved result:	{'title': 'ELBIT IMAGING LTD. ANNOUNCES ADDITIONAL BUYBACK OF NOTES SERIES I', 'pubdate': 'February 14, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/14/1725672/0/en/ELBIT-IMAGING-LTD-ANNOUNCES-ADDITIONAL-BUYBACK-OF-NOTES-SERIES-I.html', 'abstract': 'Tel Aviv, Israel, Feb.  14, 2019  (GLOBE NEWSWIRE) -- Elbit Imaging Ltd. (“EI” or the “Company”) (TASE, NASDAQ: EMITF) announced today, further to its press release dated December 27, 2018, regarding ...'}
# ------------------------------------
#
# Company name: Helios and Matheson Analytics Inc HMNY
# 	Retrieved result:	{'title': "MoviePass parent Helios & Matheson's stock to be delisted at the open, and the company won't fight it - MarketWatch", 'pubdate': 'Wed, 13 Feb 2019 13:40:00 GMT', 'link': 'https://www.marketwatch.com/story/moviepass-parent-helios-mathesons-stock-to-be-delisted-at-the-open-and-the-company-wont-fight-it-2019-02-13', 'abstract': "MoviePass parent Helios & Matheson Analytics Inc.'s stock HMNY, +0.00% will be delisted from the Nasdaq Capital Market, with the suspension of trading ..."}
# 	Retrieved result:	{'title': 'Consolidated Research: 2018 Summary Expectations for Comcast, Avnet, NIKE, Helios and Matheson Analytics, Quest Diagnostics, and Nevsun Resources — Fundamental Analysis, Key Performance Indications', 'pubdate': 'December 07, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/07/1663754/0/en/Consolidated-Research-2018-Summary-Expectations-for-Comcast-Avnet-NIKE-Helios-and-Matheson-Analytics-Quest-Diagnostics-and-Nevsun-Resources-Fundamental-Analysis-Key-Performance-Ind.html', 'abstract': 'NEW YORK, Dec.  07, 2018  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Market Source Research released its latest key findings for all current investors, ...'}
# ------------------------------------
#
# Company name: Imperva Inc IMPV
# 	Retrieved result:	{'title': 'As Imperva (IMPV) Valuation Rose, Shareholder Sheffield Asset Management Decreased Position; Kinder Morgan Del Com (KMI) Stock Value Declined While Blackhill Capital Lifted Holding by $3.32 Million - The Moveefy', 'pubdate': 'Sun, 17 Feb 2019 12:59:31 GMT', 'link': 'https://moveefy.com/2019/02/17/as-imperva-impv-valuation-rose-shareholder-sheffield-asset-management-decreased-position-kinder-morgan-del-com-kmi-stock-value-declined-while-blackhill-capital-lifted-holding-by-3-32-million/', 'abstract': 'Sheffield Asset Management Llc decreased its stake in Imperva Inc (IMPV) by 40.9% based on its latest 2018Q3 regulatory filing with the SEC. Sheffield Asset ...'}
# 	Retrieved result:	{'title': 'MERGER ALERT – IMPV and ATHN: Levi & Korsinsky, LLP Reminds Investors of Investigations Concerning the Sale of these Companies', 'pubdate': 'January 07, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/07/1681457/0/en/MERGER-ALERT-IMPV-and-ATHN-Levi-Korsinsky-LLP-Reminds-Investors-of-Investigations-Concerning-the-Sale-of-these-Companies.html', 'abstract': 'NEW YORK, Jan.  07, 2019  (GLOBE NEWSWIRE) -- The following statement is being issued by Levi & Korsinsky, LLP:  Levi & Korsinsky, LLP announces that investigations have commenced on behalf of ...'}
# ------------------------------------
#
# Company name: Loxo Oncology Inc LOXO
# 	Retrieved result:	{'title': '$-1.12 EPS Expected for Loxo Oncology, Inc. (LOXO); Shorts at Avadel Pharmaceuticals Plc – American Depositary S (AVDL) Raised By 7.49% - The Moveefy', 'pubdate': 'Sun, 10 Feb 2019 21:48:19 GMT', 'link': 'https://moveefy.com/2019/02/10/1-12-eps-expected-for-loxo-oncology-inc-loxo-shorts-at-avadel-pharmaceuticals-plc-american-depositary-s-avdl-raised-by-7-49/', 'abstract': "Analysts expect Loxo Oncology, Inc. (NASDAQ:LOXO) to report $-1.12 EPS on March, 7.They anticipate $0.43 EPS change or 62.32% from last quarter's $-0.69 ..."}
# 	Retrieved result:	{'title': 'Lilly and Loxo Oncology Announce Expiration of HSR Act Waiting Period in Connection with Proposed Transaction', 'pubdate': 'February 01, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/01/1709077/0/en/Lilly-and-Loxo-Oncology-Announce-Expiration-of-HSR-Act-Waiting-Period-in-Connection-with-Proposed-Transaction.html', 'abstract': 'INDIANAPOLIS and STAMFORD, CT, Feb.  01, 2019  (GLOBE NEWSWIRE) -- Eli Lilly and Company (NYSE: LLY) (“Lilly”) and Loxo Oncology, Inc. (NASDAQ: LOXO) (“Loxo Oncology”) today announced the expiration ...'}
# ------------------------------------
#
# Company name: MINDBODY Inc MB
# 	Retrieved result:	{'title': 'Form DEFM14A MINDBODY, Inc. - StreetInsider.com', 'pubdate': 'Wed, 23 Jan 2019 08:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+DEFM14A+MINDBODY%2C+Inc./15029780.html', 'abstract': 'StreetInsider.com Top Tickers, 2/15/2019. 1. SPY 2. NVDA 3. SSNC 4. TRUE 5. LOGM. 6. ANET 7. MAT 8. RDFN 9. FXI 10. CBS. Top News Most Read Special ...'}
# ------------------------------------
#
# Company name: MiMedx Group Inc MDXG
# 	Retrieved result:	{'title': 'MiMedx Group (MDXG) Ratings Suspended at Needham & Company - StreetInsider.com', 'pubdate': 'Thu, 06 Dec 2018 08:00:00 GMT', 'link': 'https://www.streetinsider.com/Analyst+Comments/MiMedx+Group+%28MDXG%29+Ratings+Suspended+at+Needham+%26+Company/14895556.html', 'abstract': 'News and research before you hear about it on CNBC and others. Claim your 2-week free trial to StreetInsider Premium here.'}
# 	Retrieved result:	{'title': 'Bragar Eagel & Squire, P.C. Reminds Investors that it is Investigating the Board of Directors of MiMedx Group, Inc. (MDXG) on Behalf of Stockholders and Encourages Investors to Contact the Firm', 'pubdate': 'July 03, 2018', 'link': 'https://globenewswire.com//news-release/2018/07/03/1533143/0/en/Bragar-Eagel-Squire-P-C-Reminds-Investors-that-it-is-Investigating-the-Board-of-Directors-of-MiMedx-Group-Inc-MDXG-on-Behalf-of-Stockholders-and-Encourages-Investors-to-Contact-the.html', 'abstract': 'NEW YORK, July  03, 2018  (GLOBE NEWSWIRE) -- Bragar Eagel & Squire, P.C. reminds investors that the Firm is investigating potential claims against certain officers and directors of MiMedx Group, ...'}
# ------------------------------------
#
# Company name: National American University Holdings Inc NAUH
# 	Retrieved result:	{'title': 'National American University Holdings, Inc. (NAUH) CEO Ronald Shape on Q1 2019 Results - Earnings Call Transcript - Seeking Alpha', 'pubdate': 'Thu, 11 Oct 2018 07:00:00 GMT', 'link': 'https://seekingalpha.com/article/4211165-national-american-university-holdings-inc-nauh-ceo-ronald-shape-q1-2019-results-earnings-call', 'abstract': 'National American University Holdings, Inc. (OTC:NAUH) Q1 2019 Earnings Conference Call October 11, 2018, 11:00 AM ET Executives Adam Prior - IR, The ...'}
# 	Retrieved result:	{'title': 'National American University Holdings, Inc. Appoints Academic Veteran Thomas Bickart as Chief Financial Officer', 'pubdate': 'February 15, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/15/1726153/0/en/National-American-University-Holdings-Inc-Appoints-Academic-Veteran-Thomas-Bickart-as-Chief-Financial-Officer.html', 'abstract': 'RAPID CITY, S.D., Feb.  15, 2019  (GLOBE NEWSWIRE) -- National American University Holdings, Inc. (the “Company”) (OTCQB: NAUH), which through its wholly owned subsidiary operates National American ...'}
# ------------------------------------
#
# Company name: Organogenesis Holdings Inc ORGOW
# 	Retrieved result:	{'title': 'Form 424B3 Organogenesis Holdings - StreetInsider.com', 'pubdate': 'Mon, 04 Feb 2019 13:13:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+424B3+Organogenesis+Holdings/15073088.html', 'abstract': 'The Selling Stockholders named in this prospectus or their permitted transferees may offer and sell from time to time up to 46,853,325 shares of our Class A ...'}
# ------------------------------------
#
# Company name: ReShape Lifesciences Inc RSLS
# 	Retrieved result:	{'title': 'ReShape shares halted pending news; shares up 7% - Seeking Alpha', 'pubdate': 'Mon, 26 Nov 2018 08:00:00 GMT', 'link': 'https://seekingalpha.com/news/3412151-reshape-shares-halted-pending-news-shares-7-percent', 'abstract': 'Nasdaq has suspended trading in ReShape Lifesciences ([[RSLS]] +7.2%) pending the release of news. Update: In a direct offering, the company intends to sel.'}
# 	Retrieved result:	{'title': 'Consolidated Research: 2018 Summary Expectations for Envision Healthcare, Taylor Morrison Home, Vertex Pharmaceuticals, ReShape Lifesciences Inc., American Axle & Manufacturing, and Lattice Semiconductor — Fundamental Analysis, Key Performance Indications', 'pubdate': 'March 09, 2018', 'link': 'https://globenewswire.com//news-release/2018/03/09/1419876/0/en/Consolidated-Research-2018-Summary-Expectations-for-Envision-Healthcare-Taylor-Morrison-Home-Vertex-Pharmaceuticals-ReShape-Lifesciences-Inc-American-Axle-Manufacturing-and-Lattice.html', 'abstract': 'NEW YORK, March  09, 2018  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Fundamental Markets released its latest key findings for all current investors, traders, ...'}
# ------------------------------------
#
# Company name: Real Goods Solar Inc RGSE
# 	Retrieved result:	{'title': 'REAL GOODS SOLAR, INC. (NASDAQ:RGSE) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of Listing - Market Exclusive', 'pubdate': 'Fri, 08 Feb 2019 08:00:00 GMT', 'link': 'https://marketexclusive.com/real-goods-solar-inc-nasdaqrgse-files-an-8-k-notice-of-delisting-or-failure-to-satisfy-a-continued-listing-rule-or-standard-transfer-of-listing-2/2019/02/', 'abstract': 'REAL GOODS SOLAR, INC. (NASDAQ:RGSE) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of Listing'}
# 	Retrieved result:	{'title': 'RGS Energy to Begin Trading on OTCQX Best Market', 'pubdate': 'February 08, 2019', 'link': 'https://globenewswire.com//news-release/2019/02/08/1716217/0/en/RGS-Energy-to-Begin-Trading-on-OTCQX-Best-Market.html', 'abstract': 'DENVER, Feb.  08, 2019  (GLOBE NEWSWIRE) -- RGS Energy (NASDAQ: RGSE), the exclusive worldwide manufacturer of the visually stunning POWERHOUSE™ Solar Shingle System, announced that it will move ...'}
# ------------------------------------
#
# Company name: Select Income REIT SIR
# 	Retrieved result:	{'title': 'Nordea Investment Management Ab Raised Amphastar Pharmaceuticals (AMPH) Stake by $1.24 Million; Jrm Investment Counsel Continues to Hold Holding in Select Income Reit (SIR) - The Yomi Blog', 'pubdate': 'Fri, 08 Feb 2019 11:03:33 GMT', 'link': 'https://yomiblog.com/2019/02/08/nordea-investment-management-ab-raised-amphastar-pharmaceuticals-amph-stake-by-1-24-million-jrm-investment-counsel-continues-to-hold-holding-in-select-income-reit-sir/', 'abstract': 'Nordea Investment Management Ab increased its stake in Amphastar Pharmaceuticals (AMPH) by 37.45% based on its latest 2018Q3 regulatory filing with the ...'}
# 	Retrieved result:	{'title': 'Analysis: Positioning to Benefit within Allegion, Las Vegas Sands, Select Income REIT, Utah Medical Products, Brunswick, and Lennar — Research Highlights Growth, Revenue, and Consolidated Results', 'pubdate': 'December 10, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/10/1664274/0/en/Analysis-Positioning-to-Benefit-within-Allegion-Las-Vegas-Sands-Select-Income-REIT-Utah-Medical-Products-Brunswick-and-Lennar-Research-Highlights-Growth-Revenue-and-Consolidated-Re.html', 'abstract': 'NEW YORK, Dec.  10, 2018  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Fundamental Markets released its latest key findings for all current investors, traders, ...'}
# ------------------------------------
#
# Company name: Simplicity Esports and Gaming Company WINR
# 	Retrieved result:	{'title': 'Dallas oil magnate reportedly invests $35 million in Overwatch League e-sports team - Dallas News', 'pubdate': 'Mon, 14 Aug 2017 07:00:00 GMT', 'link': 'https://www.dallasnews.com/business/sports-business/2017/08/14/dallas-oil-magnate-reportedly-invests-35-million-overwatch-leagueesports-team', 'abstract': "As the father of a teenage son, I've learned a few things by osmosis about the amazing popularity of e-sports. On a weekend not long ago when the Rocket ..."}
# 	Retrieved result:	{'title': 'Simplicity Esports and Gaming Company Announces Commencement of Trading on OTCQB', 'pubdate': 'January 25, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/25/1705580/0/en/Simplicity-Esports-and-Gaming-Company-Announces-Commencement-of-Trading-on-OTCQB.html', 'abstract': 'NEW YORK, Jan.  25, 2019  (GLOBE NEWSWIRE) -- Simplicity Esports and Gaming Company (OTCQB: WINR) (the “Company”), announced it will begin trading on January 25, 2019 on the OTCQB. Management decided ...'}
# ------------------------------------
#
# Company name: Simplicity Esports and Gaming Company WINRW
# 	Retrieved result:	{'title': 'Dallas oil magnate reportedly invests $35 million in Overwatch League e-sports team - Dallas News', 'pubdate': 'Mon, 14 Aug 2017 07:00:00 GMT', 'link': 'https://www.dallasnews.com/business/sports-business/2017/08/14/dallas-oil-magnate-reportedly-invests-35-million-overwatch-leagueesports-team', 'abstract': "As the father of a teenage son, I've learned a few things by osmosis about the amazing popularity of e-sports. On a weekend not long ago when the Rocket ..."}
# 	Retrieved result:	{'title': 'Simplicity Esports and Gaming Company Announces New Commencement Date for Trading Under its New Ticker Symbols', 'pubdate': 'January 09, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/09/1685836/0/en/Simplicity-Esports-and-Gaming-Company-Announces-New-Commencement-Date-for-Trading-Under-its-New-Ticker-Symbols.html', 'abstract': 'NEW YORK, Jan.  09, 2019  (GLOBE NEWSWIRE) -- Simplicity Esports and Gaming Company, formerly known as SMAAASH Entertainment Inc. (NASDAQ: SMSH) (the “Company”), announced today that the date for the ...'}
# ------------------------------------
#
# Company name: Super Micro Computer Inc SMCI
# 	Retrieved result:	{'title': 'Super Micro Computer (SMCI) Expects its Common Stock will Soon be Suspended from Trading on Nasdaq - StreetInsider.com', 'pubdate': 'Tue, 21 Aug 2018 07:00:00 GMT', 'link': 'https://www.streetinsider.com/Corporate+News/Super+Micro+Computer+%28SMCI%29+Expects+its+Common+Stock+will+Soon+be+Suspended+from+Trading+on+Nasdaq/14535870.html" target="_blank">Super Micro Computer (SMCI) Expects its Common Stock will Soon be Suspended from Trading on Nasdaq</a>&nbsp;&nbsp;<font color="#6f6f6f">StreetInsider.com</font></li><li><a href="https://www.fool.com/investing/2018/08/22/why-super-micro-computer-stock-plunged-today.aspx" target="_blank">Why Super Micro Computer Stock Plunged Today</a>&nbsp;&nbsp;<font color="#6f6f6f">The Motley Fool</font></li><li><a href="https://www.marketwatch.com/story/super-micros-stock-set-to-be-delisted-as-filing-deadline-wont-be-met-2018-08-22" target="_blank">Super Micro\'s stock set to be delisted as filing deadline won\'t be met</a>&nbsp;&nbsp;<font color="#6f6f6f">MarketWatch</font></li><li><a href="https://www.hpcwire.com/off-the-wire/supermicro-announces-suspension-of-trading-of-common-stock-on-nasdaq-and-its-intention-to-appeal/" target="_blank">Supermicro Announces Suspension of Trading of Common Stock on Nasdaq and its Intention to Appeal</a>&nbsp;&nbsp;<font color="#6f6f6f">HPCwire</font></li><li><a href="https://marketexclusive.com/super-micro-computer-inc-nasdaqsmci-files-an-8-k-notice-of-delisting-or-failure-to-satisfy-a-continued-listing-rule-or-standard-transfer-of-listing-4/2018/08/" target="_blank">SUPER MICRO COMPUTER, INC. (NASDAQ:SMCI) Files An 8-K Notice of Delisting or Failure to Satisfy a Continued Listing Rule or Standard; Transfer of Listing</a>&nbsp;&nbsp;<font color="#6f6f6f">Market Exclusive</font></li><li><strong><a href="https://news.google.com/stories/CAAqOQgKIjNDQklTSURvSmMzUnZjbmt0TXpZd1NoTUtFUWp6ODlfdWpJQU1FYnhnbXVaX003VnpLQUFQAQ?oc=5', 'abstract': ''}
# 	Retrieved result:	{'title': 'Bragar Eagel & Squire, P.C. Reminds Investors that it is Investigating Seaboard, Menlo, Super Micro, and NiSource on Behalf of Stockholders and Encourages Investors to Contact the Firm', 'pubdate': 'November 05, 2018', 'link': 'https://globenewswire.com//news-release/2018/11/05/1645623/0/en/Bragar-Eagel-Squire-P-C-Reminds-Investors-that-it-is-Investigating-Seaboard-Menlo-Super-Micro-and-NiSource-on-Behalf-of-Stockholders-and-Encourages-Investors-to-Contact-the-Firm.html', 'abstract': 'NEW YORK, Nov.  05, 2018  (GLOBE NEWSWIRE) -- Bragar Eagel & Squire, P.C. reminds investors that it is investigating potential claims on behalf of stockholders of Seaboard Corporation, Menlo ...'}
# ------------------------------------
#
# Company name: Waitr Holdings Inc WTRHW
# 	Retrieved result:	{'title': 'Form 8-K Waitr Holdings Inc. For: Nov 15 - StreetInsider.com', 'pubdate': 'Wed, 21 Nov 2018 08:00:00 GMT', 'link': 'https://www.streetinsider.com/SEC+Filings/Form+8-K+Waitr+Holdings+Inc.+For%3A+Nov+15/14855257.html', 'abstract': 'News and research before you hear about it on CNBC and others. Claim your 2-week free trial to StreetInsider Premium here.'}
# ------------------------------------
#
# Company name: Yulong Eco-Materials Limited YECO
# 	Retrieved result:	{'title': 'Yulong Eco-Materials Limited Announces NASDAQ Delisting - Nasdaq', 'pubdate': 'Thu, 13 Dec 2018 08:00:00 GMT', 'link': 'https://www.nasdaq.com/press-release/yulong-ecomaterials-limited-announces-nasdaq-delisting-20181213-01078', 'abstract': 'New York, Dec. 13, 2018-- Yulong Eco-Materials Limited, announced today that it has received notice from The Nasdaq Stock Market that Nasdaq will.'}
# 	Retrieved result:	{'title': 'Yulong Eco-Materials Limited Announces NASDAQ Delisting', 'pubdate': 'December 13, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/13/1667046/0/en/Yulong-Eco-Materials-Limited-Announces-NASDAQ-Delisting.html', 'abstract': 'New York, Dec.  13, 2018  (GLOBE NEWSWIRE) -- Yulong Eco-Materials Limited (NASDAQ: YECO) (the “Company”), announced today that it has received notice from The Nasdaq Stock Market (“Nasdaq”) that ...'}
# ------------------------------------
#
# Company name: athenahealth Inc ATHN
# 	Retrieved result:	{'title': 'Mcrae Capital Management Increased Its Position in Kinder Morgan Del (KMI) by $860,200 as Market Value Declined; As Athenahealth (ATHN) Market Valuation Declined, Shareholder Barton Investment Management Decreased Its Stake - Port Courier', 'pubdate': 'Sat, 16 Feb 2019 10:03:15 GMT', 'link': 'https://portcourier.com/2019/02/16/mcrae-capital-management-increased-its-position-in-kinder-morgan-del-kmi-by-860200-as-market-value-declined-as-athenahealth-athn-market-valuation-declined-shareholder-barton-investment-managem/', 'abstract': 'Mcrae Capital Management Inc increased its stake in Kinder Morgan Inc Del (KMI) by 29.35% based on its latest 2018Q3 regulatory filing with the SEC. Mcrae ...'}
# 	Retrieved result:	{'title': 'Report: Exploring Fundamental Drivers Behind Akamai Technologies, Dynex Capital, MedEquities Realty Trust, HFF, Penumbra, and athenahealth — New Horizons, Emerging Trends, and Upcoming Developments', 'pubdate': 'January 11, 2019', 'link': 'https://globenewswire.com//news-release/2019/01/11/1690417/0/en/Report-Exploring-Fundamental-Drivers-Behind-Akamai-Technologies-Dynex-Capital-MedEquities-Realty-Trust-HFF-Penumbra-and-athenahealth-New-Horizons-Emerging-Trends-and-Upcoming-Devel.html', 'abstract': 'NEW YORK, Jan.  11, 2019  (GLOBE NEWSWIRE) -- In new independent research reports released early this morning, Fundamental Markets released its latest key findings for all current investors, traders, ...'}
# ------------------------------------
#
# Company name: iPass Inc IPAS
# 	Retrieved result:	{'title': 'iPass Receives Nasdaq Listing Determination; Eligible to Trade Over-the-Counter November 7, 2018 - GlobeNewswire', 'pubdate': 'Tue, 06 Nov 2018 08:00:00 GMT', 'link': 'https://globenewswire.com/news-release/2018/11/06/1646490/0/en/iPass-Receives-Nasdaq-Listing-Determination-Eligible-to-Trade-Over-the-Counter-November-7-2018.html', 'abstract': 'REDWOOD SHORES, Calif., Nov. 06, 2018 (GLOBE NEWSWIRE) -- iPass Inc. (IPAS), a leading provider of global mobile connectivity and location technology, ...'}
# 	Retrieved result:	{'title': 'Bragar Eagel & Squire, P.C. Reminds Investors that it is Investigating the Boards of Directors of ARRIS, Athenahealth, and iPass on Behalf of Stockholders and Encourages Investors to Contact the Firm', 'pubdate': 'December 06, 2018', 'link': 'https://globenewswire.com//news-release/2018/12/07/1663540/0/en/Bragar-Eagel-Squire-P-C-Reminds-Investors-that-it-is-Investigating-the-Boards-of-Directors-of-ARRIS-Athenahealth-and-iPass-on-Behalf-of-Stockholders-and-Encourages-Investors-to-Con.html', 'abstract': 'NEW YORK, Dec.  06, 2018  (GLOBE NEWSWIRE) -- Bragar Eagel & Squire, P.C. reminds investors that it is investigating potential claims on behalf of stockholders of ARRIS International plc, ...'}
# ------------------------------------
